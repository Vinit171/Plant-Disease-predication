# %% [markdown]
# # Exploratory Data Analysis On PlantVillage Dataset
#
# In this notebook, we are going to perform EDA on plantVillage Dataset to get deep insights into our plant image data which would further help us in the next step of our project i.e. Preprocessing.

# %% [markdown]
# ## Identifying Class Imbalance
# Our very first step is Identifying Class Imbalance. We are going to find the number of images assigned to each class and plot them in a bar chart to easily identify any imbalances.

# %%
# Importing dependencies
# !pip install dask
import os
import pathlib
import pandas as pd
import matplotlib.pyplot as plt
import PIL
import PIL.Image
import numpy as np
import dask.bag
from dask.diagnostics import ProgressBar
import pandas as pd
import random
import cv2
# Out:
# Requirement already satisfied: dask in c:\python38\lib\site-packages (2022.10.0)
# Requirement already satisfied: cloudpickle>=1.1.1 in c:\python38\lib\site-packages (from dask) (2.2.0)
# Requirement already satisfied: partd>=0.3.10 in c:\python38\lib\site-packages (from dask) (1.3.0)
# Requirement already satisfied: pyyaml>=5.3.1 in c:\python38\lib\site-packages (from dask) (6.0)
# Requirement already satisfied: fsspec>=0.6.0 in c:\python38\lib\site-packages (from dask) (2022.8.2)
# Requirement already satisfied: toolz>=0.8.2 in c:\python38\lib\site-packages (from dask) (0.12.0)
# Requirement already satisfied: packaging>=20.0 in c:\python38\lib\site-packages (from dask) (21.3)
# Requirement already satisfied: pyparsing!=3.0.5,>=2.0.2 in c:\python38\lib\site-packages (from packaging>=20.0->dask) (3.0.1)
# Requirement already satisfied: locket in c:\python38\lib\site-packages (from partd>=0.3.10->dask) (1.0.0)

# %%
# Setting up dataset path
data_dir = pathlib.Path("/content/PlantVillage")
class_name = os.listdir(data_dir)
print(f"Total number of classes: {len(class_name)}")
class_name
# Out:
# Total number of classes: 15
# ['Pepper__bell___Bacterial_spot',
#  'Pepper__bell___healthy',
#  'Potato___Early_blight',
#  'Potato___healthy',
#  'Potato___Late_blight',
#  'Tomato_Bacterial_spot',
#  'Tomato_Early_blight',
#  'Tomato_healthy',
#  'Tomato_Late_blight',
#  'Tomato_Leaf_Mold',
#  'Tomato_Septoria_leaf_spot',
#  'Tomato_Spider_mites_Two_spotted_spider_mite',
#  'Tomato__Target_Spot',
#  'Tomato__Tomato_mosaic_virus',
#  'Tomato__Tomato_YellowLeaf__Curl_Virus']

# %% [markdown]
# From above code we found that there are 15 classes which consists of healthy and diseased images.

# %%
number_classes = {}
for name in class_name:
  number_classes[name] = len(os.listdir(f"{data_dir}/{name}"))

number_classes
# Out:
# {'Pepper__bell___Bacterial_spot': 997,
#  'Pepper__bell___healthy': 1478,
#  'Potato___Early_blight': 1000,
#  'Potato___healthy': 152,
#  'Potato___Late_blight': 1000,
#  'Tomato_Bacterial_spot': 2127,
#  'Tomato_Early_blight': 1000,
#  'Tomato_healthy': 1591,
#  'Tomato_Late_blight': 1909,
#  'Tomato_Leaf_Mold': 952,
#  'Tomato_Septoria_leaf_spot': 1771,
#  'Tomato_Spider_mites_Two_spotted_spider_mite': 1676,
#  'Tomato__Target_Spot': 1404,
#  'Tomato__Tomato_mosaic_virus': 373,
#  'Tomato__Tomato_YellowLeaf__Curl_Virus': 3208}

# %% [markdown]
# Above code snippt represents the classes and their respective image count

# %%
total_img = sum(list(number_classes.values()))
print(f"Total number of images in our dataset is: {total_img}")
# Out:
# Total number of images in our dataset is: 20638

# %% [markdown]
# Now, plotting the bar chart to identify imbalance in our dataset

# %%
# Figure Size
fig, ax = plt.subplots(figsize =(16, 9))

# Horizontal Bar Plot
ax.barh(list(number_classes.keys()), list(number_classes.values()))

# Remove axis splines
for s in ['top', 'bottom', 'left', 'right']:
	ax.spines[s].set_visible(False)
 
# Remove x, y Ticks
ax.xaxis.set_ticks_position('none')
ax.yaxis.set_ticks_position('none')

# Add padding between axes and labels
ax.xaxis.set_tick_params(pad = 5)
ax.yaxis.set_tick_params(pad = 10)

# Add x, y gridlines
ax.grid(b = True, color ='grey',
		linestyle ='-.', linewidth = 0.5,
		alpha = 0.2)

# Show top values
ax.invert_yaxis()


# Add annotation to bars
for i in ax.patches:
	plt.text(i.get_width()+0.2, i.get_y()+0.5,
			str(round((i.get_width()), 2)),
			fontsize = 10, fontweight ='bold',
			color ='grey')
 
# Add Plot Title
ax.set_title('Number of Images by Class',
			loc ='left', )

plt.xlabel('Images Count')
plt.ylabel('Class Names')

# Show Plot
plt.show()

# %% [markdown]
# ## Plotting Image Size
# Consistent image size is crucial for our deep learning task, mismatched matrices will bring our project to a quick stop. So, visualizing raw image size can also help us to understand our dataset better.

# %%
directories = {}
for name in class_name:
  directories[name] = f"{data_dir}/{name}/"
directories

# %%
def get_dims(file):
  """Returns dimensions for an RGB image"""
  im = PIL.Image.open(file)
  arr = np.array(im)
  h,w,d = arr.shape
  return h,w

# %%
for n,d in directories.items():
  filepath = d
  filelist = [filepath + f for f in os.listdir(filepath)]
  dims = dask.bag.from_sequence(filelist).map(get_dims)
  with dask.diagnostics.ProgressBar():
    dims = dims.compute()
    dim_df = pd.DataFrame(dims, columns=['height', 'width'])
    sizes = dim_df.groupby(['height', 'width']).size().reset_index().rename(columns={0:'count'})
    sizes.plot.scatter(x='width', y='height');
    plt.title('Image Sizes (pixels) | {}'.format(n))
# Out:
# [########################################] | 100% Completed | 2.19 s
# [########################################] | 100% Completed | 2.00 s
# [########################################] | 100% Completed | 2.31 s
# [########################################] | 100% Completed | 1.32 s
# [########################################] | 100% Completed | 1.65 s
# [########################################] | 100% Completed | 2.29 s
# [########################################] | 100% Completed | 1.65 s
# [########################################] | 100% Completed | 1.97 s
# [########################################] | 100% Completed | 2.08 s
# [########################################] | 100% Completed | 1.65 s
# [########################################] | 100% Completed | 2.23 s
# [########################################] | 100% Completed | 1.98 s
# [########################################] | 100% Completed | 1.87 s
# [########################################] | 100% Completed | 1.45 s
# [########################################] | 100% Completed | 2.78 s

# %% [markdown]
# From the above plot, we can see that our dataset contains consistent image size.

# %% [markdown]
# ## Viewing a Sampling of Images
# Finally, let’s take a look at a handful of images from each class.

# %%
plt.figure(figsize=(15,15))
index = 1
for key, value in directories.items():
  img_path = value + f"{random.choice(os.listdir(value))}"
  image = cv2.imread(img_path)
  ax = plt.subplot(5,3,index)
  index += 1
  plt.imshow(image.astype("int"))
  plt.title(key)
  plt.axis('off')
